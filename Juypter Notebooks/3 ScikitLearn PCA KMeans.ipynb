# %% [markdown]
# # Crash Attribute Segmentation of New Jersey State Vehicle Accident Data
# ## 3. PCA & K-Means Clustering using SciKit-Learn
#
# This notebook outlines the process of performing Principle Component Analysis (PCA) on the normalized Accident table generated from the previous notebook and training a SageMaker K-Means algorithm to cluster municipalities with similar crash attributes. The goal of this process is to identify crash patterns across multiple municipalities within New Jersey.
#
# ### Accidents Data
# The raw data used for this notebook was processed in the previous notebook which grouped individual crash cases by county-municipality and normalized all crash attribute columns.
#
# ### Machine Learning Workflow
# The steps for PCA and K-Means training using SciKit-Learn are as follows:
# 1. Dimensionality reduction with PCA
# 2. Feature engineering and data transformation
# 3. Clustering transformed data with k-means
# 4. Extracting trained model attributes and visualizing k clusters
#
# ### Analysis of Results
# After training PCA and K-means models from both SageMaker and SciKit-Learn, an analysis of both methods will be documented in the Capstone report.

# %%
# data managing and display libs
import pandas as pd
import numpy as np
import os
import io

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 

#scikit learn libraries
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load Normalized Accidents Table
# Load in CSV containing normalized Accident data.

# %%
crash_data_file = 'data/accidents_normalized_severity.csv'
# create a dataframe
crash_data_scaled = pd.read_csv(crash_data_file, header=0, delimiter=",") 
crash_data_scaled = crash_data_scaled.set_index('location')
print(crash_data_scaled.index)
print(crash_data_scaled.columns)
print(crash_data_scaled.shape)
crash_data_scaled.head()
# Out:
# Index(['ATLANTIC-ABSECON CITY', 'ATLANTIC-ATLANTIC CITY',
#        'ATLANTIC-BUENA BORO', 'ATLANTIC-BUENA VISTA TWP',
#        'ATLANTIC-EGG HARBOR CITY', 'ATLANTIC-EGG HARBOR TWP',
#        'ATLANTIC-ESTELL MANOR CITY', 'ATLANTIC-FOLSOM BORO',
#        'ATLANTIC-GALLOWAY TWP', 'ATLANTIC-HAMILTON TWP',
#        ...
#        'WARREN-KNOWLTON TWP', 'WARREN-LIBERTY TWP', 'WARREN-LOPATCONG TWP',
#        'WARREN-MANSFIELD TWP', 'WARREN-OXFORD TWP', 'WARREN-PHILLIPSBURG TOWN',
#        'WARREN-POHATCONG TWP', 'WARREN-WASHINGTON BORO',
#        'WARREN-WASHINGTON TWP', 'WARREN-WHITE TWP'],
#       dtype='object', name='location', length=511)
# Index(['severity_rating5_4', 'severity_rating5_5', 'intersection_N',
#        'intersection_Y', 'alcohol_involved_N', 'alcohol_involved_Y',
#        'hazmat_involved_N', 'hazmat_involved_Y', 'hs_collision_type_1',
#        'hs_collision_type_2',
#        ...
#        'first_harmful_event_57.0', 'first_harmful_event_58.0',
#        'first_harmful_event_59.0', 'first_harmful_event_60.0',
#        'first_harmful_event_61.0', 'first_harmful_event_62.0',
#        'first_harmful_event_69.0', 'first_harmful_event_99.0',
#        'flg_cell_in_use_N', 'flg_cell_in_use_Y'],
#       dtype='object', length=175)
# (511, 175)
#                           severity_rating5_4  severity_rating5_5  \
# location
# ATLANTIC-ABSECON CITY               0.031250            0.066667
# ATLANTIC-ATLANTIC CITY              0.250000            0.100000
# ATLANTIC-BUENA BORO                 0.015625            0.016667
# ATLANTIC-BUENA VISTA TWP                       0.0           0.075676
# ATLANTIC-EGG HARBOR CITY                       0.0           0.043243
#
#                           flg_cell_in_use_Y
# location
# ATLANTIC-ABSECON CITY              0.000000
# ATLANTIC-ATLANTIC CITY             0.333333
# ATLANTIC-BUENA BORO                0.000000
# ATLANTIC-BUENA VISTA TWP           0.000000
# ATLANTIC-EGG HARBOR CITY           0.000000
#
# [5 rows x 175 columns]

# %% [markdown]
# ## 1. Dimensionality reduction with PCA
# With 175 columns, it would be hard for a K-Means algorithm to cluster meaningful crash attributes. We only want attributes that hold meaningful weights and disregard those that are not importaint. To do this, the data will be dimensionally reduced using the SciKit-Learn model for PCA.
#
# ### 1.1 Define the PCA model and train

# %%
# N_COMPONENTS is current features - 1
# only a portion of these will be selected to use later
N_COMPONENTS = crash_data_scaled.columns.size - 1

pca = PCA(n_components = N_COMPONENTS)
print('\nPCA Parameters:', pca, '\n')
# Out:
# PCA Parameters: PCA(copy=True, iterated_power='auto', n_components=174, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.fit(crash_data_scaled)
print('\nArray Containing all Principal Components:\n', pca.components_)
print('\nFirst Principal Component:', pca.components_[0])
print('Second Principal Component:', pca.components_[1])
print('\nEigenvalues:', pca.singular_values_)
print('\nPercentage of Variance Explained by Each Principal Component:', pca.explained_variance_ratio_)
# Out:
# Array Containing all Principal Components:
#  [[ 1.14478121e-01  1.42293531e-01  1.40607285e-01 ...  6.17654544e-02
#    1.24219388e-01  7.00748907e-02]
#  [ 6.00340289e-02 -2.25015915e-02 -7.06268706e-03 ...  1.09092710e-01
#    3.36491614e-02  3.63884536e-02]
#  [ 4.18738925e-02  4.94860757e-03 -1.14591561e-02 ... -9.58110560e-02
#    3.08347311e-02 -1.58835202e-02]
#  ...
#  [ 0.00000000e+00 -4.02124552e-16 -4.96349095e-02 ... -1.45824253e-03
#   -6.11740370e-01 -9.92011412e-03]
#  [ 0.00000000e+00  3.81090017e-16 -3.53667159e-02 ...  2.14229539e-04
#    3.36999928e-01  5.46486369e-03]
#  [-0.00000000e+00 -7.72991772e-16  8.92834533e-02 ... -3.19131038e-03
#    1.09776737e-01  1.78016330e-03]]
#
# First Principal Component: [ 1.14478121e-01  1.42293531e-01  1.40607285e-01  9.79315195e-02
#   1.15458295e-01  1.61950055e-01  1.23590272e-01  2.64768497e-02
#   7.04873156e-02  1.23283581e-01  7.66442121e-02  1.44549700e-01
#   9.57186972e-02  1.17157574e-02  1.29394879e-01  1.14060291e-02
#   5.82072112e-03  1.39572833e-01  1.20776875e-01  1.25668218e-01
#   9.82436781e-02  6.88867499e-02  5.67049472e-02  6.91723658e-02
#   2.77820061e-02  1.26013161e-02  8.65125245e-02  1.66458049e-01
#   1.35605545e-02  7.63363317e-02  1.00396131e-01  3.89228498e-02
#   5.39494456e-03  6.76942506e-02  7.53914461e-04  4.68550185e-02
#   1.38150538e-01  6.80069263e-02  9.47596953e-03  1.30860717e-01
#   2.81044647e-02  6.22062965e-02  2.28140944e-02  6.10811854e-02
# In this project, the top n principle components will be chosen that account for 70% data varience. To choose "n", the explained varience is calculated by summing n component's explained varience until the sum reaches ~70%.

# %%
# get selected params
v = pd.DataFrame(pca.components_) # the makeups of each component
s = pd.DataFrame(pca.explained_variance_ratio_) # explained varience ratio
s.head()
# Out:
#           0
# 0  0.320972
# 1  0.046702
# 2  0.029873
# 3  0.024734
# 4  0.021892

# %%
print(v.shape)
v.head()
# Out:
# (174, 175)
#         0         1         2         3         4         5         6    \
# 0  0.114478  0.142294  0.140607  0.097932  0.115458  0.161950  0.123590
# 1  0.060034 -0.022502 -0.007063  0.093754  0.044588 -0.056626  0.033725
# 2  0.041874  0.004949 -0.011459  0.091318  0.032572  0.005437  0.029495
# 3  0.010487 -0.009632 -0.016588  0.034503  0.010775 -0.048516  0.004299
# 4 -0.006397  0.052023  0.020084  0.000699  0.016746 -0.024741  0.012762
#
#         7         8         9    ...       165       166       167       168  \
# 0  0.026477  0.070487  0.123284  ...  0.044623  0.041861  0.037540  0.122854
# 1  0.009259  0.093816  0.111492  ...  0.008688 -0.107332  0.073538 -0.265380
# 2  0.047098  0.038157  0.057140  ... -0.061635 -0.106190 -0.026187  0.013614
# 3 -0.013190  0.045981  0.008709  ...  0.122787  0.036141  0.050220  0.011184
# 4 -0.028007  0.041719  0.000379  ...  0.313113 -0.081501  0.025540  0.077512
#
#         169       170       171       172       173       174
# 0  0.024907  0.008650  0.043555  0.061765  0.124219  0.070075
# 1 -0.042443  0.024651  0.056925  0.109093  0.033649  0.036388
# 2  0.061444  0.022915  0.064345 -0.095811  0.030835 -0.015884
# 3  0.045104 -0.031485 -0.013394 -0.038472  0.002402  0.106690
# 4 -0.027926 -0.023491 -0.031012  0.275457  0.011842  0.037266
#
# [5 rows x 175 columns]

# %% [markdown]
# ### 2.2 Data Variance
# For a SciKit-Learn PCA model, the top 's' values start at the beginning. 's' values are defined as the percentage of variance explained by each of the selected components.

# %%
# looking at top 5 components
n_principal_components = 5

# print a selection of s
print(s.iloc[:n_principal_components])
# Out:
#           0
# 0  0.320972
# 1  0.046702
# 2  0.029873
# 3  0.024734
# 4  0.021892

# %% [markdown]
# ### 2.3 Calculating the explained variance
# In this project, the top n principle components will be chosen that account for 70% data varience. To choose "n", the explained varience will be calculated by summing each component's varience from the top until it reaches ~70%.
#
# Using this formula, an "n" of 25 resulted in 71% data varience.

# %%
# Calculate the explained variance for the top n principal components
def explained_variance(s, n_top_components):
    '''Calculates the approx. data variance that n_top_components captures.
       :param s: A dataframe of singular values for top components; 
           the top value is in the last row.
       :param n_top_components: An integer, the number of top components to use.
       :return: The expected data variance covered by the n_top_components.'''
    
    # calculate approx variance
    exp_variance = s.iloc[:n_top_components].sum()
    
    return exp_variance[0]

# %%
n_top_components = 25 # select a value for the number of top components

# calculate the explained variance
exp_variance = explained_variance(s, n_top_components)
print('Explained variance: ', exp_variance)
# Out:
# Explained variance:  0.7095655306872247

# %% [markdown]
# ### 2.4 Component Makeup
# The following code examines the makeup of each PCA component based on the weightings of the original features that are included in the component.
# To reuse the `display_component` function from the previous notebook, the v dataframe was transposed such that features (175) are rows and components (174) are columns.

# %%
import seaborn as sns

def display_component(v, features_list, component_num, n_weights=10):
    
    # get index of component (component_num)
    row_idx = component_num

    # get the list of weights from a row in v, dataframe
    v_1_row = v.iloc[:, row_idx]
    ##print(v_1_row)
    v_1 = np.squeeze(v_1_row.values)
    # match weights to features in counties_scaled dataframe, using list comporehension
    comps = pd.DataFrame(list(zip(v_1, features_list)), 
                         columns=['weights', 'features'])

    # we'll want to sort by the largest n_weights
    # weights can be neg/pos and we'll sort by magnitude
    comps['abs_weights']=comps['weights'].apply(lambda x: np.abs(x))
    sorted_weight_data = comps.sort_values('abs_weights', ascending=False).head(n_weights)

    # display using seaborn
    ax=plt.subplots(figsize=(10,6))
    ax=sns.barplot(data=sorted_weight_data, 
                   x="weights", 
                   y="features", 
                   palette="Blues_d"
                  )
    ax.set_title("SciKit-Learn PCA Component Makeup, Component #" + str(component_num + 1))
    plt.savefig("processed_data/scikit-learn/images/c_" + str(component_num + 1) + ".png", bbox_inches='tight')
    plt.show()

# %%
transpose_v = v.T
print(transpose_v.shape)
transpose_v.iloc[:,:]
# Out:
# (175, 174)
#           0         1         2         3         4         5         6    \
# 0    0.114478  0.060034  0.041874  0.010487 -0.006397 -0.002449  0.003584
# 1    0.142294 -0.022502  0.004949 -0.009632  0.052023  0.014285  0.017964
# 2    0.140607 -0.007063 -0.011459 -0.016588  0.020084 -0.009757  0.008860
# 3    0.097932  0.093754  0.091318  0.034503  0.000699  0.021530  0.007160
# 4    0.115458  0.044588  0.032572  0.010775  0.016746  0.000513  0.010231
# ..        ...       ...       ...       ...       ...       ...       ...
# 170  0.008650  0.024651  0.022915 -0.031485 -0.023491  0.016071 -0.007805
# 171  0.043555  0.056925  0.064345 -0.013394 -0.031012  0.129579 -0.006017
# 172  0.061765  0.109093 -0.095811 -0.038472  0.275457 -0.311724 -0.162654
# 173  0.124219  0.033649  0.030835  0.002402  0.011842  0.002231  0.008211
# 174  0.070075  0.036388 -0.015884  0.106690  0.037266  0.043615  0.005854
#
#           7         8         9    ...           164           165  \
# 0   -0.007228 -0.019929  0.000158  ...  0.000000e+00 -0.000000e+00
# 1    0.025835 -0.004464 -0.018088  ...  2.316415e-16  4.837334e-16
# 2    0.007800 -0.014043 -0.010007  ...  4.263656e-02  3.089922e-01
# 3   -0.003272 -0.016394  0.000733  ...  2.893195e-02  2.096733e-01
# 4    0.012269 -0.021428 -0.006387  ... -3.184086e-01  2.121086e-01
# ..        ...       ...       ...  ...           ...           ...
# 170  0.015610 -0.007412 -0.036762  ... -3.374731e-03 -5.373475e-03
# 171  0.003397 -0.062419  0.020494  ... -6.749462e-03 -1.074695e-02
# 172 -0.077225  0.289692  0.400786  ... -1.687366e-03 -2.686738e-03
# 173  0.004149 -0.014991 -0.005596  ...  1.136768e-01 -1.335223e-02
# 174 -0.047549 -0.015170 -0.009911  ...  1.843408e-03 -2.165226e-04
#
#               166           167           168           169           170  \
# 0    0.000000e+00  0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# 1    1.511155e-16 -4.008094e-16  3.182611e-17  2.584406e-16 -1.794522e-16
# 2    5.108788e-03 -5.793217e-02 -8.207997e-03 -6.145368e-02  1.890470e-01
# 3    3.466678e-03 -3.931111e-02 -5.569712e-03 -4.170071e-02  1.282819e-01
# 4    7.886702e-02 -4.418915e-02  7.342796e-02  1.888759e-01 -4.385142e-01
# ..            ...           ...           ...           ...           ...
# 170 -5.004580e-03  6.345726e-03 -6.099742e-03 -3.924989e-03  5.022377e-03
# 171 -1.000916e-02  1.269145e-02 -1.219948e-02 -7.849978e-03  1.004475e-02
# 172 -2.502290e-03  3.172863e-03 -3.049871e-03 -1.962495e-03  2.511189e-03
# 173  3.580455e-01  7.524092e-02  1.338996e-01 -3.270146e-01  1.629719e-01
# 174  5.806143e-03  1.220123e-03  2.171345e-03 -5.302940e-03  2.642788e-03
#
#               171           172           173
# 0    0.000000e+00  0.000000e+00 -0.000000e+00
# 1   -4.021246e-16  3.810900e-16 -7.729918e-16
# 2   -4.963491e-02 -3.536672e-02  8.928345e-02
# 3   -3.368083e-02 -2.399884e-02  6.058520e-02
# 4   -3.228555e-02  2.675582e-01  2.182293e-01
# ..            ...           ...           ...
# 170 -2.916485e-03  4.284591e-04 -6.382621e-03
# 171 -5.832970e-03  8.569182e-04 -1.276524e-02
# 172 -1.458243e-03  2.142295e-04 -3.191310e-03
# 173 -6.117404e-01  3.369999e-01  1.097767e-01
# 174 -9.920114e-03  5.464864e-03  1.780163e-03
#
# [175 rows x 174 columns]

# %%
# display makeup of first component
for num in range(25):
    display_component(transpose_v, crash_data_scaled.columns.values, component_num=num)

# %% [markdown]
# ### 2.5 Dimensionally reduce the PCA components
# The code in this section details how the resulting PCA components were reduced to the top n components. A dataframe is created based on the top n components for each county-municipality data point.

# %%
data_transformed = pca.transform(crash_data_scaled) # returns shape (n_samples, n_components)
transformed_df = pd.DataFrame(data_transformed)

# %%
print(transformed_df.shape)
transformed_df.head()
# Out:
# (511, 174)
#         0         1         2         3         4         5         6    \
# 0 -0.258861  0.014501  0.020325 -0.081433  0.048150 -0.057623 -0.057928
# 1  0.771225  0.359157  0.287680 -0.001793  0.044035  0.114233 -0.073310
# 2 -0.378835 -0.072236 -0.075397  0.435153 -0.122853  0.010625  0.051016
# 3  0.112528 -0.313396 -0.036641  0.397123 -0.139602  0.076991 -0.046225
# 4 -0.311690  0.010645  0.136297  0.008828  0.004250 -0.017810  0.018226
#
#         7         8         9    ...           164           165  \
# 0  0.035114  0.107243  0.033827  ... -4.208195e-17  9.130003e-17
# 1 -0.182439 -0.130033  0.105368  ... -1.118468e-17 -4.439496e-16
# 2 -0.115615  0.131223  0.026250  ...  5.663602e-18  5.940416e-17
# 3 -0.126018  0.151448  0.113910  ... -2.544636e-16 -4.995753e-18
# 4 -0.038281 -0.047999  0.021742  ... -1.327213e-16  2.660366e-17
#
#             166           167           168           169           170  \
# 0 -4.531461e-18  1.082940e-17 -2.035797e-17 -8.138120e-17  7.109298e-17
# 1  1.595274e-16  2.032482e-16  1.927424e-16 -1.114691e-16 -2.815138e-17
# 2 -2.567340e-17  1.791059e-17 -2.577898e-17  5.539090e-17  5.153669e-17
# 3  3.509613e-17  1.297325e-16 -3.073921e-17  1.274090e-16  8.629385e-18
# 4  6.811008e-17 -9.593064e-17  6.483321e-17 -8.658340e-18  2.513636e-17
#
#             171           172           173
# 0  1.311134e-17  3.109055e-17 -6.690280e-16
# 1 -4.021889e-19  3.354634e-17  1.976142e-16
# 2 -5.882547e-17  1.875775e-17 -1.084548e-16
# 3  1.235240e-17  1.897906e-16  6.058040e-16
# 4 -2.873886e-17  3.485815e-17 -4.764460e-17
#
# [5 rows x 174 columns]

# %%
# create dimensionality-reduced data. this function keeps the top n-component columns and applies the 
# county-muni titles as the returned dataframe's index 

def create_transformed_df(transformed_df, crash_data_scaled, n_top_components):
    # create new dataframe to add data to
    crash_transformed = pd.DataFrame()
    
    # capture columns before n_top_components
    crash_transformed = transformed_df.iloc[:, :n_top_components]
    crash_transformed.index=crash_data_scaled.index
    
    return crash_transformed

# %%
crash_data_transform = create_transformed_df(transformed_df, crash_data_scaled, n_top_components)
PCA_list = []
# add descriptive columns
for x in range(n_top_components):
    num = x + 1
    PCA_list.append("c_" + str(num))

#PCA_list=['c_1', 'c_2', 'c_3', 'c_4', 'c_5', 'c_6', 'c_7', 'c_8', 'c_9', 'c_10', 'c_11', 'c_12', 'c_13']
print(PCA_list)
crash_data_transform.columns = PCA_list 

crash_data_transform.head()
# Out:
# ['c_1', 'c_2', 'c_3', 'c_4', 'c_5', 'c_6', 'c_7', 'c_8', 'c_9', 'c_10', 'c_11', 'c_12', 'c_13', 'c_14', 'c_15', 'c_16', 'c_17', 'c_18', 'c_19', 'c_20', 'c_21', 'c_22', 'c_23', 'c_24', 'c_25']
#                                c_1       c_2       c_3       c_4       c_5  \
# location
# ATLANTIC-ABSECON CITY    -0.258861  0.014501  0.020325 -0.081433  0.048150
# ATLANTIC-ATLANTIC CITY    0.771225  0.359157  0.287680 -0.001793  0.044035
# ATLANTIC-BUENA BORO      -0.378835 -0.072236 -0.075397  0.435153 -0.122853
# ATLANTIC-BUENA VISTA TWP  0.112528 -0.313396 -0.036641  0.397123 -0.139602
# ATLANTIC-EGG HARBOR CITY -0.311690  0.010645  0.136297  0.008828  0.004250
#
#                                c_6       c_7       c_8       c_9      c_10  \
# location
# ATLANTIC-ABSECON CITY    -0.057623 -0.057928  0.035114  0.107243  0.033827
# ATLANTIC-ATLANTIC CITY    0.114233 -0.073310 -0.182439 -0.130033  0.105368
# ATLANTIC-BUENA BORO       0.010625  0.051016 -0.115615  0.131223  0.026250
# ATLANTIC-BUENA VISTA TWP  0.076991 -0.046225 -0.126018  0.151448  0.113910
# ATLANTIC-EGG HARBOR CITY -0.017810  0.018226 -0.038281 -0.047999  0.021742
#
#                           ...      c_16      c_17      c_18      c_19  \
# location                  ...
# ATLANTIC-ABSECON CITY     ...  0.074602  0.022651  0.086213 -0.045274
# ATLANTIC-ATLANTIC CITY    ...  0.075960 -0.055333 -0.270728  0.071233
# ATLANTIC-BUENA BORO       ...  0.042477  0.025886  0.051307 -0.067645
# ATLANTIC-BUENA VISTA TWP  ...  0.014682 -0.014678 -0.011860 -0.202232
# ATLANTIC-EGG HARBOR CITY  ...  0.009009  0.009084 -0.005980  0.026823
#
#                               c_20      c_21      c_22      c_23      c_24  \
# location
# ATLANTIC-ABSECON CITY     0.287012 -0.103475 -0.028544  0.043530 -0.032650
# ATLANTIC-ATLANTIC CITY    0.194768 -0.173416 -0.023707 -0.045139 -0.098290
# ATLANTIC-BUENA BORO      -0.058094 -0.038722 -0.077201  0.022989  0.012893
# ATLANTIC-BUENA VISTA TWP  0.054808  0.012896 -0.036583 -0.000539 -0.001588
# ATLANTIC-EGG HARBOR CITY -0.008449 -0.018210 -0.016987 -0.018936  0.018670
#
#                               c_25
# location
# ATLANTIC-ABSECON CITY    -0.009566
# ATLANTIC-ATLANTIC CITY   -0.036079
# ATLANTIC-BUENA BORO       0.001263
# ATLANTIC-BUENA VISTA TWP -0.014771
# ATLANTIC-EGG HARBOR CITY -0.019170
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3. Clustering transformed data with k-means
# With the Accidents data dimensionally reduced to contain 25 PCA attributes, a K-means model will be trained to segment municipalities by similar attributes.
# The following code defines a built-in K-means estimator in SciKit-Learn. The "k" chosen is based on empirical data.

# %%
# define a KMeans estimator
kmeans = KMeans(init='k-means++', n_clusters=8, n_init=100)
kmeans.fit(crash_data_transform)
cluster_info = kmeans.predict(crash_data_transform) # returns ndarray of shape (n_samples)

# %% [markdown]
# ## 4. Extracting trained model attributes and visualizing k clusters
# ### 4.1 Visualize the distribution of data over clusters
#
# Get the cluster labels for each county-municipality data point and visualize the distribution of points over each cluster.

# %%
# get all cluster labels
cluster_labels = kmeans.labels_
cluster_df = pd.DataFrame(cluster_labels)[0].value_counts()
print(cluster_df)
# Out:
# 0    328
# 2    133
# 1     23
# 5     15
# 3      8
# 7      2
# 6      1
# 4      1
# Name: 0, dtype: int64

# %%
# another method of visualizing the distribution
# display a histogram of cluster counts
ax =plt.subplots(figsize=(6,3))
ax = plt.hist(cluster_labels, bins=15,  range=(-0.5, 7.5), color='blue', rwidth=0.5)

title="Histogram of Cluster Counts"
plt.title(title, fontsize=12)
plt.show()

# %% [markdown]
# ### 4.2 Access the k-means model attributes
# The following code extracts the cluster centroids and converts them into a dataframe for visual analysis.

# %%
cluster_centers = kmeans.cluster_centers_ # returns ndarray of shape (n_clusters, n_features)
cluster_centroids = pd.DataFrame(cluster_centers)
cluster_centroids.columns = crash_data_transform.columns
print(cluster_centroids.shape)
display(cluster_centroids)
# Out:
# (8, 25)
#         c_1       c_2       c_3       c_4       c_5       c_6       c_7  \
# 0 -0.395208  0.044530  0.017857  0.012175  0.000608  0.002937  0.008281
# 1  1.214792 -0.008034  0.140433 -0.174137 -0.109636 -0.013142  0.057259
# 2  0.240356 -0.074398 -0.066329 -0.023525  0.016166 -0.019020 -0.039404
# 3  2.668374  0.686083 -0.280872  0.124685 -0.223033 -0.077707 -0.012601
# 4  6.388394  2.485705 -0.634243  1.381483  1.745732 -0.817760 -0.579996
# 5  2.001603 -0.927768  0.044654  0.172052  0.135054  0.120543  0.117713
# 6  3.549162  0.988422 -1.146778 -0.859984 -0.529852  2.236730 -0.387318
# 7  4.206029  0.213901  1.546524 -0.479533 -0.642711 -0.368493  0.255051
#
#         c_8       c_9      c_10  ...      c_16      c_17      c_18      c_19  \
# 0  0.004205  0.005999  0.002873  ... -0.008480  0.002363  0.002466  0.000096
# 1  0.041767  0.028564 -0.107774  ...  0.021913 -0.003108 -0.111643 -0.130901
# 2 -0.004373 -0.022936 -0.003735  ...  0.024668 -0.003762  0.002271  0.021812
# 3 -0.254644 -0.136865  0.225707  ... -0.139000  0.018266  0.174185 -0.085447
# 4  1.193890 -0.275265 -0.407486  ... -0.363802 -0.022682 -0.432917  0.065840
# 5 -0.039899  0.033159  0.050263  ... -0.016549 -0.052291  0.028011 -0.014013
# 6  0.858536  0.835432  0.168932  ...  1.074253  0.236045  0.263901  0.039504
# 7 -0.587543  0.231696 -0.143881  ... -0.176725  0.110814 -0.093768  0.433408
#
#        c_20      c_21      c_22      c_23      c_24      c_25
# 0 -0.004029 -0.011744 -0.003457  0.004333 -0.001675  0.008680
# 1  0.033389  0.112941  0.107866  0.011067  0.033463 -0.060892
# 2  0.002312  0.018344  0.001502 -0.014129 -0.000126 -0.018518
# 3 -0.005786  0.037746 -0.184600 -0.061486  0.011756  0.021726
# 4 -0.347401 -0.466056  0.171940  0.076530 -0.206197  0.172818
# 5  0.016248 -0.041678 -0.019730  0.047034 -0.018631  0.008099
# 6 -0.075373  0.189757 -0.035996 -0.175704  0.443671  0.351846
# 7  0.235653 -0.292859  0.045059  0.044420 -0.127734  0.098208
#
# [8 rows x 25 columns]

# %% [markdown]
# ### 4.3 Visualizing Centroids in Component Space
# The following heatmap shows centroids of each cluster against their makeup of each PCA component. Based on this heatmap, clusters 1 and 3 have the highest values in component c_1. This means that county-municipalities within cluster 1 or 3 have similar crash attributes that are described in component c_1.

# %%
# generate a heatmap in component space, using the seaborn library
plt.figure(figsize = (12,9))
ax = sns.heatmap(cluster_centroids.T, cmap = 'YlGnBu', annot=True)
ax.set_xlabel("Cluster")
ax.set_title("Attribute Value by Centroid (SciKit-Learn)")
plt.show()

# %% [markdown]
# ### 4.4 Natural Groupings
#
# The following code maps the cluster labels back to each individual county-municipality data point. This is helpful when examining which counties are naturally grouped together.

# %%
# add a 'labels' column to the dataframe
crash_data_transform['labels']=list(map(int, cluster_labels))
# Out:
# /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
# MONMOUTH-FREEHOLD TWP          0.221173 -0.056025 -0.311043       1
# MONMOUTH-NEPTUNE TWP           0.246262  0.617820  0.129454       1
# MONMOUTH-WALL TWP             -0.374649  0.059233  0.098769       1
# MORRIS-PARSIPPANY-TROY HILLS   0.380280  0.239372  0.286847       1
# OCEAN-BRICK TWP               -0.321989  0.057874 -0.038162       1
# OCEAN-MANCHESTER TWP           0.327198  0.108102 -0.007727       1
# SOMERSET-BRIDGEWATER TWP      -0.096810 -0.259655  0.073267       1
# SOMERSET-FRANKLIN TWP         -0.442982  0.646774  0.492269       1
# UNION-ELIZABETH CITY           0.295419 -0.179503 -0.327423       1
# UNION-LINDEN CITY             -0.246229  0.073195 -0.064442       1
# UNION-UNION TWP                0.264479 -0.115089 -0.134340       1
#
# [23 rows x 26 columns]

# %%
folder = 'processed_data/scikit-learn/'
cluster.to_csv(folder + 'cluster.csv')
crash_data_scaled.to_csv(folder + 'crash_data_scaled.csv')
cluster_centroids.to_csv(folder + 'cluster_centroids.csv')
cluster_df.to_csv(folder + 'cluster_df.csv')

# %% [markdown]
# ## Analysis of Results
# The results from training the PCA and K-means models from this notebook will be discussed in the Capstone report.

# %%
for i in range(0,8):
    cluster_temp=crash_data_transform[crash_data_transform['labels']==i]
    print(i)
    print(cluster_temp.index.tolist())
# Out:
# 0
# ['ATLANTIC-ABSECON CITY', 'ATLANTIC-BUENA BORO', 'ATLANTIC-EGG HARBOR CITY', 'ATLANTIC-ESTELL MANOR CITY', 'ATLANTIC-FOLSOM BORO', 'ATLANTIC-LINWOOD CITY', 'ATLANTIC-LONGPORT BORO', 'ATLANTIC-MARGATE CITY', 'ATLANTIC-NORTHFIELD CITY', 'ATLANTIC-PORT REPUBLIC CITY', 'ATLANTIC-SOMERS POINT CITY', 'ATLANTIC-VENTNOR CITY', 'ATLANTIC-WEYMOUTH TWP', 'BERGEN-ALLENDALE BORO', 'BERGEN-ALPINE BORO', 'BERGEN-BERGENFIELD BORO', 'BERGEN-BOGOTA BORO', 'BERGEN-CARLSTADT BORO', 'BERGEN-CLIFFSIDE PARK BORO', 'BERGEN-CLOSTER BORO', 'BERGEN-CRESSKILL BORO', 'BERGEN-DEMAREST BORO', 'BERGEN-DUMONT BORO', 'BERGEN-EDGEWATER BORO', 'BERGEN-EMERSON BORO', 'BERGEN-ENGLEWOOD CLIFFS BORO', 'BERGEN-FAIR LAWN BORO', 'BERGEN-FAIRVIEW BORO', 'BERGEN-GARFIELD CITY', 'BERGEN-GLEN ROCK BORO', 'BERGEN-HARRINGTON PARK BORO', 'BERGEN-HASBROUCK HEIGHTS BORO', 'BERGEN-HILLSDALE BORO', 'BERGEN-HO HO KUS BORO', 'BERGEN-LEONIA BORO', 'BERGEN-LITTLE FERRY BORO', 'BERGEN-LODI BORO', 'BERGEN-LYNDHURST TWP', 'BERGEN-MAYWOOD BORO', 'BERGEN-MIDLAND PARK BORO', 'BERGEN-MONTVALE BORO', 'BERGEN-MOONACHIE BORO', 'BERGEN-NEW MILFORD BORO', 'BERGEN-NORTH ARLINGTON BORO', 'BERGEN-NORTHVALE BORO', 'BERGEN-NORWOOD BORO', 'BERGEN-OAKLAND BORO', 'BERGEN-OLD TAPPAN BORO', 'BERGEN-ORADELL BORO', 'BERGEN-PALISADES PARK BORO', 'BERGEN-PARK RIDGE BORO', 'BERGEN-RAMSEY BORO', 'BERGEN-RIDGEFIELD BORO', 'BERGEN-RIDGEWOOD VILLAGE', 'BERGEN-RIVER EDGE BORO', 'BERGEN-RIVER VALE TWP', 'BERGEN-ROCHELLE PARK TWP', 'BERGEN-SADDLE RIVER BORO', 'BERGEN-SOUTH HACKENSACK TWP', 'BERGEN-TENAFLY BORO', 'BERGEN-TETERBORO BORO', 'BERGEN-UPPER SADDLE RIVER BORO', 'BERGEN-WALDWICK BORO', 'BERGEN-WALLINGTON BORO', 'BERGEN-WASHINGTON TWP', 'BERGEN-WESTWOOD BORO', 'BERGEN-WOOD-RIDGE BORO', 'BERGEN-WOODCLIFF LAKE BORO', 'BERGEN-WYCKOFF TWP', 'BURLINGTON-BEVERLY CITY', 'BURLINGTON-BORDENTOWN CITY', 'BURLINGTON-BURLINGTON CITY', 'BURLINGTON-CHESTERFIELD TWP', 'BURLINGTON-CINNAMINSON TWP', 'BURLINGTON-EASTAMPTON TWP', 'BURLINGTON-EDGEWATER PARK TWP', 'BURLINGTON-HAINESPORT TWP', 'BURLINGTON-MEDFORD LAKES BORO', 'BURLINGTON-MOUNT HOLLY TWP', 'BURLINGTON-NEW HANOVER TWP', 'BURLINGTON-NORTH HANOVER TWP', 'BURLINGTON-PALMYRA BORO', 'BURLINGTON-PEMBERTON BORO', 'BURLINGTON-RIVERSIDE TWP', 'BURLINGTON-SHAMONG TWP', 'BURLINGTON-SPRINGFIELD TWP', 'BURLINGTON-WASHINGTON TWP', 'BURLINGTON-WILLINGBORO TWP', 'CAMDEN-AUDUBON BORO', 'CAMDEN-BARRINGTON BORO', 'CAMDEN-BERLIN BORO', 'CAMDEN-BERLIN TWP', 'CAMDEN-BROOKLAWN BORO', 'CAMDEN-CHESILHURST BORO', 'CAMDEN-CLEMENTON BORO', 'CAMDEN-COLLINGSWOOD BORO', 'CAMDEN-GIBBSBORO BORO', 'CAMDEN-HADDON HEIGHTS BORO', 'CAMDEN-HADDON TWP', 'CAMDEN-HADDONFIELD BORO', 'CAMDEN-LAUREL SPRINGS BORO', 'CAMDEN-LAWNSIDE BORO', 'CAMDEN-LINDENWOLD BORO', 'CAMDEN-MERCHANTVILLE BORO', 'CAMDEN-MOUNT EPHRIAM BORO', 'CAMDEN-OAKLYN BORO', 'CAMDEN-PINE HILL BORO', 'CAMDEN-RUNNEMEDE BORO', 'CAMDEN-SOMERDALE BORO', 'CAMDEN-STRATFORD BORO', 'CAMDEN-WATERFORD TWP', 'CAMDEN-WOODLYNNE BORO', 'CAPE MAY-AVALON BORO', 'CAPE MAY-CAPE MAY CITY', 'CAPE MAY-NORTH WILDWOOD CITY', 'CAPE MAY-OCEAN CITY', 'CAPE MAY-SEA ISLE CITY', 'CAPE MAY-STONE HARBOR BORO', 'CAPE MAY-WILDWOOD CITY', 'CAPE MAY-WILDWOOD CREST BORO', 'CAPE MAY-WOODBINE BORO', 'CUMBERLAND-COMMERCIAL TWP', 'CUMBERLAND-DEERFIELD TWP', 'CUMBERLAND-DOWNE TWP', 'CUMBERLAND-GREENWICH TWP', 'CUMBERLAND-HOPEWELL TWP', 'CUMBERLAND-LAWRENCE TWP', 'CUMBERLAND-STOW CREEK TWP', 'CUMBERLAND-UPPER DEERFIELD TWP', 'ESSEX-CALDWELL BORO', 'ESSEX-CEDAR GROVE TWP', 'ESSEX-ESSEX FELLS BORO', 'ESSEX-GLEN RIDGE BORO', 'ESSEX-MAPLEWOOD TWP', 'ESSEX-MILLBURN TWP', 'ESSEX-ORANGE CITY', 'ESSEX-ROSELAND BORO', 'ESSEX-SOUTH ORANGE VILLAGE TWP', 'ESSEX-VERONA TWP', 'ESSEX-WEST CALDWELL TWP', 'GLOUCESTER-CLAYTON BORO', 'GLOUCESTER-GREENWICH TWP', 'GLOUCESTER-NEWFIELD BORO', 'GLOUCESTER-PAULSBORO BORO', 'GLOUCESTER-PITMAN BORO', 'GLOUCESTER-SOUTH HARRISON TWP', 'GLOUCESTER-WENONAH BORO', 'GLOUCESTER-WESTVILLE BORO', 'GLOUCESTER-WOODBURY CITY', 'GLOUCESTER-WOODBURY HEIGHTS BORO', 'HUDSON-GUTTE ...
# 1
# ['ATLANTIC-GALLOWAY TWP', 'ATLANTIC-PLEASANTVILLE CITY', 'BURLINGTON-PEMBERTON TWP', 'CAMDEN-GLOUCESTER TWP', 'CAMDEN-MAGNOLIA BORO', 'CAMDEN-PENNSAUKEN TWP', 'CUMBERLAND-MILLVILLE CITY', 'MERCER-TRENTON CITY', 'MIDDLESEX-CRANBURY TWP', 'MIDDLESEX-EAST BRUNSWICK TWP', 'MIDDLESEX-SAYREVILLE BORO', 'MIDDLESEX-SOUTH BRUNSWICK TWP', 'MONMOUTH-FREEHOLD TWP', 'MONMOUTH-NEPTUNE TWP', 'MONMOUTH-WALL TWP', 'MORRIS-PARSIPPANY-TROY HILLS', 'OCEAN-BRICK TWP', 'OCEAN-MANCHESTER TWP', 'SOMERSET-BRIDGEWATER TWP', 'SOMERSET-FRANKLIN TWP', 'UNION-ELIZABETH CITY', 'UNION-LINDEN CITY', 'UNION-UNION TWP']
# 2
# ['ATLANTIC-ATLANTIC CITY', 'ATLANTIC-BUENA VISTA TWP', 'ATLANTIC-HAMMONTON TOWN', 'ATLANTIC-MULLICA TWP', 'BERGEN-EAST RUTHERFORD BORO', 'BERGEN-ELMWOOD PARK BORO', 'BERGEN-ENGLEWOOD CITY', 'BERGEN-FORT LEE BORO', 'BERGEN-FRANKLIN LAKES BORO', 'BERGEN-HACKENSACK CITY', 'BERGEN-MAHWAH TWP', 'BERGEN-PARAMUS BORO', 'BERGEN-RIDGEFIELD PARK VILLAGE', 'BERGEN-RUTHERFORD BORO', 'BERGEN-SADDLE BROOK TWP', 'BERGEN-TEANECK TWP', 'BURLINGTON-BASS RIVER TWP', 'BURLINGTON-BORDENTOWN TWP', 'BURLINGTON-BURLINGTON TWP', 'BURLINGTON-DELRAN TWP', 'BURLINGTON-EVESHAM TWP', 'BURLINGTON-FLORENCE TWP', 'BURLINGTON-LUMBERTON TWP', 'BURLINGTON-MANSFIELD TWP', 'BURLINGTON-MAPLE SHADE TWP', 'BURLINGTON-MEDFORD TWP', 'BURLINGTON-MOORESTOWN TWP', 'BURLINGTON-SOUTHAMPTON TWP', 'BURLINGTON-TABERNACLE TWP', 'BURLINGTON-WESTAMPTON TWP', 'BURLINGTON-WOODLAND TWP', 'CAMDEN-BELLMAWR BORO', 'CAMDEN-GLOUCESTER CITY', 'CAMDEN-VOORHEES TWP', 'CAPE MAY-DENNIS TWP', 'CAPE MAY-LOWER TWP', 'CUMBERLAND-BRIDGETON CITY', 'CUMBERLAND-FAIRFIELD TWP', 'ESSEX-BELLEVILLE TWP', 'ESSEX-BLOOMFIELD TWP', 'ESSEX-EAST ORANGE CITY', 'ESSEX-FAIRFIELD BORO', 'ESSEX-IRVINGTON TWP', 'ESSEX-LIVINGSTON TWP', 'ESSEX-MONTCLAIR TWP', 'ESSEX-NUTLEY TWP', 'ESSEX-WEST ORANGE TWP', 'GLOUCESTER-EAST GREENWICH TWP', 'GLOUCESTER-ELK TWP', 'GLOUCESTER-GLASSBORO BORO', 'GLOUCESTER-HARRISON TWP', 'GLOUCESTER-LOGAN TWP', 'GLOUCESTER-MANTUA TWP', 'GLOUCESTER-WASHINGTON TWP', 'GLOUCESTER-WEST DEPTFORD TWP', 'GLOUCESTER-WOOLWICH TWP', 'HUDSON-BAYONNE CITY', 'HUDSON-KEARNY TOWN', 'HUDSON-NORTH BERGEN TWP', 'HUDSON-SECAUCUS TOWN', 'HUNTERDON-CLINTON TWP', 'HUNTERDON-LEBANON TWP', 'HUNTERDON-RARITAN TWP', 'HUNTERDON-READINGTON TWP', 'HUNTERDON-TEWKSBURY TWP', 'MERCER-EAST WINDSOR TWP', 'MERCER-EWING TWP', 'MERCER-HOPEWELL TWP', 'MERCER-LAWRENCE TWP', 'MERCER-PRINCETON', 'MERCER-ROBBINSVILLE TWP', 'MERCER-WEST WINDSOR TWP', 'MIDDLESEX-MONROE TWP', 'MIDDLESEX-NORTH BRUNSWICK TWP', 'MIDDLESEX-PERTH AMBOY CITY', 'MIDDLESEX-PISCATAWAY TWP', 'MONMOUTH-ABERDEEN TWP', 'MONMOUTH-EATONTOWN BORO', 'MONMOUTH-HAZLET TWP', 'MONMOUTH-HOLMDEL TWP', 'MONMOUTH-KEYPORT BORO', 'MONMOUTH-MARLBORO TWP', 'MONMOUTH-MILLSTONE TWP', 'MONMOUTH-TINTON FALLS BORO', 'MONMOUTH-UPPER FREEHOLD TWP', 'MORRIS-DENVILLE TWP', 'MORRIS-EAST HANOVER TWP', 'MORRIS-MONTVILLE TWP', 'MORRIS-MOUNT OLIVE TWP', 'MORRIS-ROCKAWAY TWP', 'MORRIS-ROXBURY TWP', 'OCEAN-BARNEGAT TWP', 'OCEAN-BERKELEY TWP', 'OCEAN-LACEY TWP', 'OCEAN-LITTLE EGG HARBOR TWP', 'OCEAN-OCEAN TWP', 'OCEAN-PLUMSTED TWP', 'OCEAN-STAFFORD TWP', 'PASSAIC-LITTLE FALLS TWP', 'PASSAIC-PASSAIC CITY', 'PASSAIC-RINGWOOD BORO', 'PASSAIC-WEST MILFORD TWP', 'SALEM-CARNEYS POINT TWP', 'SALEM-PILESGROVE TWP', 'SALEM-PITTSGROVE TWP', 'SALEM-QUINTON TWP', 'SALEM-UPPER PITTSGROVE TWP', 'SOMERSET-BEDMINSTER TWP', 'SOMERSET-BERNARDS TWP', 'SOMERSET-HILLSBOROUGH TWP', 'SOMERSET-MONTGOMERY TWP', 'SOMERSET-WARREN TWP', 'SOMERSET-WATCHUNG BORO', 'SUSSEX-ANDOVER TWP', 'SUSSEX-MONTAGUE TWP', 'SUSSEX-SPARTA TWP', 'SUSSEX-VERNON TWP', 'SUSSEX-WANTAGE TWP', 'UNION-CLARK TWP', 'UNION-CRANFORD TWP', 'UNION-HILLSIDE TWP', 'UNION-PLAINFIELD CITY', 'UNION-RAHWAY CITY', 'UNION-SCOTCH PLAINS TWP', 'UNION-SPRINGFIELD TWP', 'WARREN-ALLAMUCHY TWP', 'WARREN-GREENWICH TWP', 'WARREN-HOPE TWP', 'WARREN-KNOWLTON TWP', 'WARREN-MANSFIELD TWP', 'WARREN-POHATCONG TWP', 'WARREN-WASHINGTON TWP', 'WARREN-WHITE TWP']
# 3
# ['CAMDEN-CHERRY HILL TWP', 'HUDSON-JERSEY CITY', 'MERCER-HAMILTON TWP', 'MIDDLESEX-EDISON TWP', 'MIDDLESEX-WOODBRIDGE TWP', 'PASSAIC-CLIFTON CITY', 'PASSAIC-PATERSON CITY', 'PASSAIC-WAYNE TWP']
# 4
# ['ESSEX-NEWARK CITY']
# 5
# ['ATLANTIC-EGG HARBOR TWP', 'ATLANTIC-HAMILTON TWP', 'BURLINGTON-MOUNT LAUREL TWP', 'CAMDEN-WINSLOW TWP', 'CAPE MAY-MIDDLE TWP', 'CAPE MAY-UPPER TWP', 'CUMBERLAND-MAURICE RIVER TWP', 'CUMBERLAND-VINELAND CITY', 'GLOUCESTER-DEPTFORD TWP', 'GLOUCESTER-FRANKLIN TWP', 'GLOUCESTER-MONROE TWP', 'MIDDLESEX-OLD BRIDGE TWP', 'MONMOUTH-HOWELL TWP', 'MONMOUTH-MIDDLETOWN TWP', 'OCEAN-JACKSON TWP']
# 6
# ['CAMDEN-CAMDEN CITY']
# 7
# ['OCEAN-LAKEWOOD TWP', 'OCEAN-TOMS RIVER TWP']
